# %%
import pandas as pd
import json

# %%
data = pd.read_json('/content/drive/MyDrive/Electronics.json', lines=True, nrows = 200)

# %% [markdown]
# This describes the shape of the data by giving information regarding the number of rows and columns. since the data is very large, it keeps on crashing again and again so only 200 rows

# %%
data.shape
# Out:
# (200, 12)

# %% [markdown]
# The head of the data helps to understand the attributes as what columns are in the dataset. Moreover, it also gives insgight of the first 5 rows data values.

# %%
data.head()
# Out:
#                                     _id      reviewerID        asin  \
# 0  {'$oid': '5a13242d741a2384e88f3c11'}  A2WNBOD3WNDNKT  0439886341
# 1  {'$oid': '5a13242d741a2384e88f3c0f'}   AKM1MP6P0OYPR  0132793040
# 2  {'$oid': '5a13242d741a2384e88f3c12'}  A2CX7LUOHB2NDG  0321732944
# 3  {'$oid': '5a13242d741a2384e88f3c10'}  A2NWSAGRHCP8N5  0439886341
# 4  {'$oid': '5a13242d741a2384e88f3c13'}  A1GI0U4ZRJA8WN  0439886341
#
#            reviewerName helpful  \
# 0                   JAL  [1, 1]
# 1  Vicki Gibson "momo4"  [1, 1]
# 2                Bernie  [0, 0]
# 3           bowmans2007  [1, 1]
# 4             Truthfull  [4, 4]
#
#                                           reviewText  overall  \
# 0  Some of the functions did not work properly.  ...        3
# 1  Corey Barker does a great job of explaining Bl...        5
# 2  While many beginner DVDs try to teach you ever...        5
# 3  It never worked. My daughter worked to earn th...        1
# ...

# %% [markdown]
# The tail of the data helps to understand the data values in last 5 rows dataset.

# %%
data.tail()
# Out:
#                                       _id      reviewerID        asin  \
# 195  {'$oid': '5a13242d741a2384e88f3cd7'}  A3BMUBUC1N77U8  0972683275
# 196  {'$oid': '5a13242d741a2384e88f3cd6'}  A1EDI0X3GI1SK7  0972683275
# 197  {'$oid': '5a13242d741a2384e88f3cd8'}  A1WSLZ5AVVHLRX  0972683275
# 198  {'$oid': '5a13242d741a2384e88f3cd9'}  A2ZBW1GVAXYGNI  0972683275
# 199  {'$oid': '5a13242d741a2384e88f3cdc'}   ARG1JEPRCUDQT  0972683275
#
#          reviewerName helpful  \
# 195          ahoffoss  [0, 0]
# 196               AGW  [0, 1]
# 197          aicha s.  [0, 0]
# 198            akebia  [0, 1]
# 199  Alaskan Customer  [0, 0]
#
#                                             reviewText  overall  \
# 195  This mount works really well once you get it u...        4
# 196  Great deal, easy to mount and it appears to be...        5
# 197  I really like item ! It's perfect for the usag...        5
# 198  It probably would have been good, but the wron...        1
# ...

# %% [markdown]
# The info function fives information regarding all the columns present in the dataset and along with their datatypes.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   _id             200 non-null    object
#  1   reviewerID      200 non-null    object
#  2   asin            200 non-null    object
#  3   reviewerName    192 non-null    object
#  4   helpful         200 non-null    object
#  5   reviewText      200 non-null    object
#  6   overall         200 non-null    int64
#  7   summary         200 non-null    object
#  8   unixReviewTime  200 non-null    int64
#  9   reviewTime      200 non-null    object
#  10  category        200 non-null    object
#  11  class           200 non-null    int64
# dtypes: int64(3), object(9)
# memory usage: 18.9+ KB
